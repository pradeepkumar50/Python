# %%
# if statements

# If the condition is true, the block of code inside the if statement is executed
# If the condition is false, the code block is skipped

age = 20

if age >= 18:
    print("you are an adult")
    print("you can vote")
    print("you have full legal rights")

# Using a boolean variable

is_logged_in = True
if is_logged_in:
    print("welcome back")
 
# 0 "" None  and empty collections are treated as False. Everything else treated
# as True

# Else Statement

# The else statement executes a block of code if the condition in the if statement
# is false

# The else statement is executed when the if condition evaluate to False

student_age = 18

if student_age < 18:
    print("bad")
else:
    print("good")
# Out:
# you are an adult
# you can vote
# you have full legal rights
# welcome back
# good

# %%
# elif 
# the elif statement allows to check the multiple statements. It stands for
# else if

name = "pradeep kumar kairamkonda"

if name == "mani rathan":
    print("he is a software engineer")
elif name == "prashanth reddy":
    print("he is a govt employee")
elif name == "pradeep kumar kairamkonda":
    print("he is a artificial and machine learning engineer")
else:
    print("you entered wrong")
# Out:
# he is a artificial and machine learning engineer

# %%
# Nested conditional statements

num = int(input("Enter a number"))

if num > 0:
    print("The number is a positive")
    if num % 2 == 0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is zero or Negitive")
# Out:
# The number is zero or Negitive

# %%
# shorthand if 

a = 5
b = 10

if a < b: print("b is greater than a")
# Out:
# b is greater than a
