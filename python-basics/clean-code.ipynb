# %%
# constant cannot be changed during the execution of the program

# costants are used to represent the values that are known to be unchanging, su
# such as mathematical or physical contants

# example

# constants are written in all capital letters with underscores seperating the word

GRAVITY = 9.81
print(GRAVITY)
# Out:
# 9.81
# 5.11

# %%
# Boolean

# Boolean always starts with is and has

# %%
# Indentaiton

# It is the spacing of code to indicate its logical struccture

# use 4 spaces per level of indentation

# %%
# Lines best practices

# You should limit all lines to a maximum of 79 characters
# you can increase the line length limit up to 99 characters, if comments and 
# docstrings are wrapped at 72 charaters

# Select the recommended maximum line length for Python code:

# 79

#  Select the recommended maximum line length for comments and docstrings in Python:

# 72

# If the development team agrees on increasing the line length limit for 
# the current project, then this length should be limited to a maximum of 99 
# characters for lines of code and 72 characters for comments and docstrings.

# final_grade = ((first_grade
#                 + second_grade
#                 + third_grade
#                 + fourth_grade)/4)

# %%
# Out:
# CEO
#      Manager A
#           Employee A1
#           Employee A2
#      Manager B
#           Employee B1
# None
