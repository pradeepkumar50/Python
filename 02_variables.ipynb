# %%
# variables are used to store data.
name = "pradeep kumar kairamkonda"
age = 25
height = 5.7
is_valid = False

# printing the variables
print(name, age, height, is_valid)

# Naming convention
# variables name should be descriptive
# It starts with letters, underscore_character 
# A variable cannot start with the number
# variables names are case sensitive

# valid variable names
first_name = "pradeep kumar"
last_name = "kairamkonda"

# Invalid variable names
# 2age = 20                       # It throws error
# first-name = "pradeep"
# @name = "Kumar"

# case sensitivity

name = "pradeep"
Name = "pradeep"
# Out:
# pradeep kumar kairamkonda 25 5.7 False

# %%
# Understanding the variable types
# python is dynamically typed, type of a variable is determined at runtime

age = 25         # integer
height =  5.7    # float
name = "pradeep" # string

print(type(age), type(height), type(name))

# type checking and conversion

age = 25
print(type(age))

# type conversion
age_str = str(age)
print(age_str, type(age_str))
# Out:
# <class 'int'> <class 'float'> <class 'str'>
# <class 'int'>
# 25 <class 'str'>
